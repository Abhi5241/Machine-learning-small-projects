# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv("Datasets/Telecom Churn.csv")

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
df.tail()
# Out:
#      state  account length  area code phone number international plan  \
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 3328             yes                     36              156.2
# 3329              no                      0              231.1
# 3330              no                      0              180.8
# 3331              no                      0              213.8
# 3332             yes                     25              234.4
#
#       total day calls  total day charge  ...  total eve calls  \
# 3328               77             26.55  ...              126
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
print(f'The Number of row are in the dataset is {df.shape[0]} and the number of independent columns is {df.shape[1]-1}')
# Out:
# The Number of row are in the dataset is 3333 and the number of independent columns is 20

# %%
summary_all=round(df.describe(include="all").T,2)

# %%
summary_categoricalData=round(df.describe(include="object").T,2)

# %%
summary_categoricalData
# Out:
#                    count unique       top  freq
# state               3333     51        WV   106
# phone number        3333   3333  382-4657     1
# international plan  3333      2        no  3010
# voice mail plan     3333      2        no  2411

# %%
df.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
df['state'].unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
df['churn'].value_counts(normalize=True)
# Out:
# churn
# False    0.855086
# True     0.144914
# Name: proportion, dtype: float64

# %%
df[['state','churn']].groupby("churn").count()
# Out:
#        state
# churn
# False   2850
# True     483

# %%
df.pivot_table(values=['account length',"total day calls"],index=["international plan","churn"],aggfunc="mean")
# Out:
#                           account length  total day calls
# international plan churn
# no                 False      100.607733       100.159535
#                    True       101.777457       102.346821
# yes                False      103.456989       102.053763
#                    True       104.905109        98.781022

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# Pictorial EDA

# %% [markdown]
# Univariate analysis:-

# %% [markdown]
# catogorical column

# %%
ax=sns.countplot(data=df,x="international plan")
ax.set(title="Plan Distribution",xlabel="International Plan",ylabel="No of Customers")
plt.show()

# %% [markdown]
# Numerical column

# %%
ax=sns.displot(data=df,x="account length");
ax.set(title="Account Length Distribution",xlabel="Account Length",ylabel="No of Customers")
plt.show()

# %%
ax=sns.histplot(data=df,x="total night calls");
ax.set(title="Night Calls Distribution",xlabel="Total Night Calls",ylabel="No of Customers")
plt.show()

# %%
df.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
num=[]
cat=[]
for i in df.columns:
    if(df[i].dtype!=object):
        num.append(i)
    else:
        cat.append(i)

# %%
num.remove("churn")

# %%
df[num]
# Out:
#       account length  area code  number vmail messages  total day minutes  \
# 0                128        415                     25              265.1
# 1                107        415                     26              161.6
# 2                137        415                      0              243.4
# 3                 84        408                      0              299.4
# 4                 75        415                      0              166.7
# ...              ...        ...                    ...                ...
# 3328             192        415                     36              156.2
# 3329              68        415                      0              231.1
# 3330              28        510                      0              180.8
# 3331             184        510                      0              213.8
# 3332              74        415                     25              234.4
#
#       total day calls  total day charge  total eve minutes  total eve calls  \
# ...

# %%
cat
# Out:
# ['state', 'phone number', 'international plan', 'voice mail plan']

# %%
plt.figure(figsize=(15,10))
sns.heatmap(round(df[num].corr(),2),annot=True)
# Out:
# <Axes: >

# %%
num
# Out:
# ['account length',
#  'area code',
#  'number vmail messages',
#  'total day minutes',
#  'total day calls',
#  'total day charge',
#  'total eve minutes',
#  'total eve calls',
#  'total eve charge',
#  'total night minutes',
#  'total night calls',
#  'total night charge',
#  'total intl minutes',
#  'total intl calls',
#  'total intl charge',
#  'customer service calls']

# %%
for i in num:
    ax=sns.boxplot(data=df,x=i)
    ax.set(title=f"{i} Distribution",xlabel=f"{i} charge",ylabel="No of Customers")
    plt.show()

# %% [markdown]
# Outlier remove stretagy

# %%
def removeOutliers( col):
    Q1=df[col].quantile(0.25)
    Q3=df[col].quantile(0.75)
    IQR=Q3-Q1
    lb=Q1- 1.5* IQR
    ub=Q3+ 1.5* IQR
    return lb,ub

# %%
for i in num:
    lb,ub=removeOutliers(i)
    df[i]=np.where(df[i] >ub,ub,df[i])
    df[i]=np.where(df[i] <lb,lb,df[i])

# %%
for i in num:
    ax=sns.boxplot(data=df,x=i)
    ax.set(title=f"{i} Distribution",xlabel=f"{i} charge",ylabel="No of Customers")
    plt.show()

# %% [markdown]
# """Hierarchical cluster"""

# %%
from scipy.cluster.hierarchy import dendrogram,linkage

# %%
df.drop("state",axis=1,inplace=True)

# %%
final_df=df.iloc[:,:-1]

# %%
output_df=df.iloc[:,-1]

# %%
final_df.replace(to_replace=["no","yes"],value=[0,1],inplace = True)
# Out:
# C:\Users\chauh\AppData\Local\Temp\ipykernel_15216\2647521756.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   final_df.replace(to_replace=["no","yes"],value=[0,1],inplace = True)

# %%
final_df.drop('phone number',axis=1,inplace=True)

# %%
final_df
# Out:
#       account length  area code phone number  international plan  \
# 0              128.0      415.0     382-4657                   0
# 1              107.0      415.0     371-7191                   0
# 2              137.0      415.0     358-1921                   0
# 3               84.0      408.0     375-9999                   1
# 4               75.0      415.0     330-6626                   1
# ...              ...        ...          ...                 ...
# 3328           192.0      415.0     414-4276                   0
# 3329            68.0      415.0     370-3271                   0
# 3330            28.0      510.0     328-8230                   0
# 3331           184.0      510.0     364-6381                   1
# 3332            74.0      415.0     400-4344                   0
#
#       voice mail plan  number vmail messages  total day minutes  \
# 0                   1                   25.0              265.1
# ...

# %%
warlink=linkage(final_df,method="ward")

# %%
plt.figure(figsize=(12,8))
dendrogram(warlink,truncate_mode='lastp',p=10);

# %%
from scipy.cluster.hierarchy import fcluster

# %%
hie_clus=fcluster(warlink,3,criterion="maxclust")

# %%
hie_clus
# Out:
# array([2, 3, 2, ..., 1, 1, 2], dtype=int32)

# %%
final_df['Hie_Clus']=hie_clus

# %%
final_df
# Out:
#       account length  area code  international plan  voice mail plan  \
# 0              128.0      415.0                   0                1
# 1              107.0      415.0                   0                1
# 2              137.0      415.0                   0                0
# 3               84.0      408.0                   1                0
# 4               75.0      415.0                   1                0
# ...              ...        ...                 ...              ...
# 3328           192.0      415.0                   0                1
# 3329            68.0      415.0                   0                0
# 3330            28.0      510.0                   0                0
# 3331           184.0      510.0                   1                0
# 3332            74.0      415.0                   0                1
#
#       number vmail messages  total day minutes  total day calls  \
# 0                      25.0              265.1            110.0
# ...

# %%
final_df.pivot_table(values=num,index=['Hie_Clus'],aggfunc="mean").T
# Out:
# Hie_Clus                         1           2           3
# account length          100.129167  102.594993   99.745815
# area code               510.000000  412.644330  412.650220
# customer service calls    1.539286    1.457290    1.452423
# number vmail messages     8.019048    8.424890    7.767401
# total day calls         100.158333  100.280560  100.937885
# total day charge         30.406750   36.287084   23.848388
# total day minutes       178.860060  213.450589  140.280969
# total eve calls          99.676786  100.505523  100.028194
# total eve charge         17.113357   16.355619   17.939683
# total eve minutes       201.328869  192.418078  211.052687
# total intl calls          4.341667    4.418999    4.493392
# total intl charge         2.742702    2.772202    2.785573
# total intl minutes       10.156548   10.265096   10.314537
# total night calls       100.579762   99.271723  100.731278
# total night charge        9.006071    9.063406    9.029414
# ...

# %%
final_df.drop("Hie_Clus",axis=1,inplace=True)

# %% [markdown]
# Kmeans clustering

# %%
from sklearn.preprocessing import StandardScaler

# %%
x=StandardScaler()

# %%
final_df_sc=x.fit_transform(final_df)

# %%
final_df_sc
# Out:
# array([[ 0.68107846, -0.52360328, -0.32758048, ..., -0.62713082,
#         -0.09439897, -0.43024898],
#        [ 0.15128601, -0.52360328, -0.32758048, ..., -0.62713082,
#          1.26737806, -0.43024898],
#        [ 0.90813236, -0.52360328, -0.32758048, ...,  0.25315009,
#          0.70904948, -1.33356857],
#        ...,
#        [-1.84174272,  1.71881732, -0.32758048, ...,  0.69329055,
#          1.41717354,  0.47307061],
#        [ 2.09385832,  1.71881732,  3.05268496, ...,  2.45385237,
#         -1.93279797,  0.47307061],
#        [-0.68124498, -0.52360328, -0.32758048, ..., -0.18699037,
#          1.26737806, -1.33356857]])

# %%
from sklearn.cluster import KMeans,DBSCAN

# %%
k_mean=KMeans(n_clusters=2)
k_mean.fit(final_df_sc)
# Out:
# KMeans(n_clusters=2)

# %%
print(k_mean.labels_)
print(k_mean.inertia_)
# Out:
# [1 1 1 ... 1 0 1]
# 55821.380522132386

# %%
k_mean=KMeans(n_clusters=3)
k_mean.fit(final_df_sc)
print(k_mean.labels_)
print(k_mean.inertia_)
# Out:
# [0 0 1 ... 1 2 0]
# 50397.56168422209

# %%
k_mean=KMeans(n_clusters=10)
k_mean.fit(final_df_sc)
print(k_mean.labels_)
print(k_mean.inertia_)
# Out:
# [5 5 7 ... 3 1 0]
# 41870.46041429402

# %%
inertia=[]
for i in range(1,20):
    k_mean=KMeans(n_clusters=i)
    k_mean.fit(final_df_sc)
    inertia.append(k_mean.inertia_)

# %%
inertia
# Out:
# [59994.0,
#  53601.776638727206,
#  50427.873819718574,
#  48154.22196593848,
#  45965.89629951817,
#  44492.29319255788,
#  43845.12832160429,
#  42411.532465981654,
#  41433.90276953035,
#  41562.98049037052,
#  40113.2232624238,
#  39250.89058574573,
#  38720.94403696181,
#  38290.23260342925,
#  38064.82002894488,
#  37537.21972171618,
#  37352.41943184758,
#  36684.55693545854,
#  36237.451981144]

# %%
plt.plot(range(1,20),inertia)

# %%
k_mean=KMeans(n_clusters=2)
k_mean.fit(final_df_sc)
# Out:
# KMeans(n_clusters=2)

# %%
final_df["KMeans_clus"]=k_mean.labels_

# %%
final_df
# Out:
#       account length  area code  international plan  voice mail plan  \
# 0              128.0      415.0                   0                1
# 1              107.0      415.0                   0                1
# 2              137.0      415.0                   0                0
# 3               84.0      408.0                   1                0
# 4               75.0      415.0                   1                0
# ...              ...        ...                 ...              ...
# 3328           192.0      415.0                   0                1
# 3329            68.0      415.0                   0                0
# 3330            28.0      510.0                   0                0
# 3331           184.0      510.0                   1                0
# 3332            74.0      415.0                   0                1
#
#       number vmail messages  total day minutes  total day calls  \
# 0                      25.0              265.1            110.0
# ...
